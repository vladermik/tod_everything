# %% [markdown]
# 1. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume".

# %%
import pandas as pd
a = pd.read_csv('sp500hst.txt')
a.columns =["date", "ticker", "open", "high", "low", "close", "volume"]
a
# Out:
#            date ticker   open     high     low  close   volume
# 0      20090824      A  25.64  25.7400  25.330  25.50  22247.0
# 1      20090825      A  25.50  25.7000  25.225  25.34  30891.0
# 2      20090826      A  25.32  25.6425  25.145  25.48  33334.0
# 3      20090827      A  25.50  25.5700  25.230  25.54  70176.0
# 4      20090828      A  25.67  26.0500  25.630  25.83  39694.0
# ...         ...    ...    ...      ...     ...    ...      ...
# 36060  20090930    EIX  33.93  34.0400  33.290  33.58  30162.0
# 36061  20091001    EIX  33.59  33.5900  33.000  33.00  23996.0
# 36062  20091002    EIX  32.75  32.7500  32.390  32.52  21276.0
# 36063  20091005    EIX  32.57  32.8700  32.260  32.87  30877.0
# 36064  20091006    EIX   3.00      NaN     NaN    NaN      NaN
#
# [36065 rows x 7 columns]

# %% [markdown]
# 2. Рассчитайте среднее значение показателей для каждого из столбцов c номерами 3-6.

# %%
print( a['date'].mean(),"\n", a['open'].mean(),"\n", a['high'].mean(),"\n", a['low'].mean(),"\n", a['close'].mean(),"\n", a['volume'].mean())
# Out:
# 20097110.014751144
#  44.70709967281297
#  45.24337253771075
#  44.144186959294586
#  44.71844671694765
#  110962.12034161491

# %% [markdown]
# 3.Добавьте столбец, содержащий только число месяца, к которому относится дата.

# %%
a["month"] = a["date"]//100%100
a
# Out:
#             date ticker   open     high     low  close  volume  month
# 0       20090824      A  25.64  25.7400  25.330  25.50   22247      8
# 1       20090825      A  25.50  25.7000  25.225  25.34   30891      8
# 2       20090826      A  25.32  25.6425  25.145  25.48   33334      8
# 3       20090827      A  25.50  25.5700  25.230  25.54   70176      8
# 4       20090828      A  25.67  26.0500  25.630  25.83   39694      8
# ...          ...    ...    ...      ...     ...    ...     ...    ...
# 122568  20100813    ZMH  51.72  51.9000  51.380  51.44   14561      8
# 122569  20100816    ZMH  51.13  51.4700  50.600  51.00   13489      8
# 122570  20100817    ZMH  51.14  51.6000  50.890  51.21   20498      8
# 122571  20100819    ZMH  51.63  51.6300  50.170  50.22   18259      8
# 122572  20100820    ZMH  50.03  50.5500  49.480  49.82   17792      8
#
# [122573 rows x 8 columns]

# %% [markdown]
# 4. Рассчитайте суммарный объем торгов для для одинаковых значений тикеров.

# %%
print(a.groupby(['ticker'])['volume'].sum())
# Out:
# ticker
# A        8574578
# AA      81898998
# AAPL    52261170
# ABC      9006756
# ABT     18975870
#           ...
# XTO     21297931
# YHOO    56837171
# YUM     10971538
# ZION    15551119
# ZMH      4938916
# Name: volume, Length: 524, dtype: int64

# %% [markdown]
# 5. Загрузите данные из файла sp500hst.txt и обозначьте столбцы в соответствии с содержимым: "date", "ticker", "open", "high", "low", "close", "volume". Добавьте столбец с расшифровкой названия тикера, используя данные из файла sp_data2.csv . В случае нехватки данных об именах тикеров корректно обработать их.

# %% [markdown]
# 1.1 В файлах recipes_sample.csv и reviews_sample.csv находится информация об рецептах блюд и отзывах на эти рецепты соответственно. Загрузите данные из файлов в виде pd.DataFrame с названиями recipes и reviews. Обратите внимание на корректное считывание столбца с индексами в таблице reviews (безымянный столбец).

# %%
import pandas as pd
recipes = pd.read_csv('recipes_sample.csv')
reviews = pd.read_csv('/content/reviews_sample.csv')
print(recipes)
print(reviews)
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id   submitted  n_steps  \
# 0               35193  2002-10-25      NaN
# 1               91970  2003-07-26      NaN
# ...

# %% [markdown]
# 1.2 Для каждой из таблиц выведите основные параметры:
#
# количество точек данных (строк);
# количество столбцов;
# тип данных каждого столбца.

# %%
print('Количество строк','\n', 'recipes:', len(recipes.axes[0]),'\n','reviews:', len(reviews.axes[0]),'\n' )
print('Количество столбцов','\n', 'recipes:', len(recipes.axes[1]),'\n','reviews:', len(reviews.axes[1]),'\n' )
print( 'Типы данных','\n','\n', 'recipes:','\n', recipes.dtypes,'\n','\n', 'reviews:','\n' ,reviews.dtypes)
# Out:
# Количество строк
#  recipes: 30000
#  reviews: 126696
#
# Количество столбцов
#  recipes: 8
#  reviews: 6
#
# Типы данных
#
#  recipes:
#  name               object
# id                  int64
# minutes             int64
# contributor_id      int64
# submitted          object
# n_steps           float64
# description        object
# n_ingredients     float64
# dtype: object
#
#  reviews:
#  Unnamed: 0     int64
# user_id        int64
# recipe_id      int64
# date          object
# rating         int64
# review        object
# dtype: object

# %% [markdown]
# 1.3 Исследуйте, в каких столбцах таблиц содержатся пропуски. Посчитайте долю строк, содержащих пропуски, в отношении к общему количеству строк.

# %%
print('Количество пропусков в столбце','\n','\n','recipes:','\n', recipes.isnull().sum (),'\n','\n','reviews:','\n', reviews.isnull().sum (),'\n')
print('Доля строк','\n','\n', sum([True for idx,row in recipes.iterrows() if any(row.isnull())])/len(recipes.axes[0]),'\n','\n',sum([True for idx,row in reviews.iterrows() if any(row.isnull())])/len(reviews.axes[0]) )
# Out:
# Количество пропусков в столбце
#
#  recipes:
#  name                  0
# id                    0
# minutes               0
# contributor_id        0
# submitted             0
# n_steps           11190
# description         623
# n_ingredients      8880
# dtype: int64
#
#  reviews:
#  Unnamed: 0     0
# user_id        0
# recipe_id      0
# date           0
# rating         0
# review        17
# dtype: int64
#
# Доля строк
#
#  0.5684666666666667
#
#  0.00013417945317926376

# %% [markdown]
# 1.4 Рассчитайте среднее значение для каждого из числовых столбцов (где это имеет смысл).

# %%
print('reviews','\n', '  rating', round(reviews['rating'].mean(), 2),'\n')
print('recipes','\n', 'minutes', round(recipes['minutes'].mean(), 2),'\n')
print('n_ingredients', round(recipes['n_ingredients'].mean(), 2),'\n')
print('n_steps', round(recipes['n_steps'].mean(), 2),'\n')
# Out:
# reviews
#    rating 4.41
#
# recipes
#  minutes 123.36
#
# n_ingredients 9.01
#
# n_steps 9.81

# %% [markdown]
# 1.5 Создайте серию из 10 случайных названий рецептов.

# %%
l=recipes.sample(n = 10)
print('10 рандомных рецептов:','\n', l)
# Out:
# 10 рандомных рецептов:
#                                                      name      id  minutes  \
# 13730                          hidden veggie sloppy joes  433060       40
# 28190                                  turkey fried rice  271802       60
# 21431                                potato rolled tacos  208401       55
# 28593                    vegan egg replacer   substitute  203168        5
# 1131                                        arroz c atum  158917       40
# 27170                                      texas brisket  326347     1680
# 4583                cantaloupe salad  insalata di melone  165285       10
# 4237   butternut pumpkin  squash   roasted hazelnut a...  352900       60
# 25764                     squash casserole with dressing  110554       40
# 5599                  chicken and noodles with dumplings   30963      120
#
#        contributor_id   submitted  n_steps  \
# 13730          228458  2010-07-23      NaN
# ...

# %% [markdown]
# 1.6 Измените индекс в таблице reviews, пронумеровав строки, начиная с нуля.

# %%
?

# %% [markdown]
# 1.7 Выведите информацию о рецептах, время выполнения которых не больше 20 минут и кол-во ингредиентов в которых не больше 5.

# %%
f = recipes[recipes['minutes'] <= 20]
f = f[f['n_ingredients'] <= 5]
print(f)
# Out:
#                                                     name      id  minutes  \
# 28                                   quick biscuit bread  302399       20
# 60                         peas  fit for a king or queen  303944       20
# 90                     hawaiian sunrise           mimosa  100837        5
# 91            tasty dish s   banana pudding in 2 minutes  286484        2
# 94                                    1 minute meatballs   11361       13
# ...                                                  ...     ...      ...
# 29873  zip and steam red potatoes with butter and garlic  304922       13
# 29874                          ziplock vanilla ice cream   74250       10
# 29905                      zucchini and corn with cheese  256177       15
# 29980               zucchini with jalapeno monterey jack  320622       10
# 29983                          zucchini with serrano ham  162411       15
#
#        contributor_id   submitted  n_steps  \
# ...

# %% [markdown]
# 2.1 Преобразуйте столбец submitted из таблицы recipes в формат времени. Модифицируйте решение задачи 1.1 так, чтобы считать столбец сразу в нужном формате.

# %%
recipes['submitted'] = pd.to_datetime(recipes['submitted'])
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 2.2 Выведите информацию о рецептах, добавленных в датасет не позже 2010 года.

# %%
df = recipes[recipes['submitted'] >= '2010-01-01']
df
# Out:
#                                                     name      id  minutes  \
# 8                     1 in canada chocolate chip cookies  453467       45
# 13               blepandekager   danish   apple pancakes  503475       50
# 36                                 5 minute bread  pizza  487173       45
# 39                    bacon cheeseburger and fries  soup  447429       60
# 47                        full cool  macaroni and cheese  463219       25
# ...                                                  ...     ...      ...
# 29965                         zucchini sausage casserole  472482       80
# 29976                                      zucchini tots  505053       20
# 29992  zucchini  courgette soup  good for weight watc...  415406       45
# 29994                                     zuppa by luisa  464576       70
# 29998                                        zydeco soup  486161       60
#
#        contributor_id  submitted  n_steps  \
# ...

# %% [markdown]
# 3.1 Добавьте в таблицу recipes столбец description_length, в котором хранится длина описания рецепта из столбца description.

# %%
k = []
t = recipes['description'].tolist()
for i in t:
    k.append(len(str(i)))
recipes['description_length'] = k
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.2 Измените название каждого рецепта в таблице recipes таким образом, чтобы каждое слово в названии начиналось с прописной буквы.

# %%
k = []
t = recipes['name'].tolist()
for i in t:
    k.append(i.lower())
recipes['name'] = k
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 3.3 Добавьте в таблицу recipes столбец name_word_count, в котором хранится количество слов из названии рецепта (считайте, что слова в названии разделяются только пробелами). Обратите внимание, что между словами может располагаться несколько пробелов подряд.

# %%
k = []
t = recipes['name'].tolist()
for i in t:
    k.append(len(i.split()))
recipes['name_word_count'] = k
recipes
# Out:
#                                                name      id  minutes  \
# 0             george s at the cove  black bean soup   44123       90
# 1                healthy for them  yogurt popsicles   67664       10
# 2                      i can t believe it s spinach   38798       30
# 3                              italian  gut busters   35173       45
# 4          love is in the air  beef fondue   sauces   84797       25
# ...                                             ...     ...      ...
# 29995  zurie s holey rustic olive and cheddar bread  267661       80
# 29996          zwetschgenkuchen  bavarian plum cake  386977      240
# 29997   zwiebelkuchen   southwest german onion cake  103312       75
# 29998                                   zydeco soup  486161       60
# 29999        cookies by design   cookies on a stick  298512       29
#
#        contributor_id  submitted  n_steps  \
# 0               35193 2002-10-25      NaN
# 1               91970 2003-07-26      NaN
# ...

# %% [markdown]
# 4.1 Посчитайте количество рецептов, представленных каждым из участников (contributor_id). Какой участник добавил максимальное кол-во рецептов?

# %%
f = recipes.groupby(['contributor_id']).count()['name']
print('Cамый активный пользователь', f[f == f.max()])
f
# Out:
# Cамый активный пользователь contributor_id
# 89831    421
# Name: name, dtype: int64
# contributor_id
# 1530            5
# 1533          186
# 1534           50
# 1535           40
# 1538            8
#              ...
# 2001968497      2
# 2002059754      1
# 2002234079      1
# 2002234259      1
# 2002247884      1
# Name: name, Length: 8404, dtype: int64

# %% [markdown]
# 4.2 Посчитайте средний рейтинг к каждому из рецептов. Для скольких рецептов отсутствуют отзывы? Обратите внимание, что отзыв с нулевым рейтингом или не заполненным текстовым описанием не считается отсутствующим.

# %%
f = round(reviews.groupby(['recipe_id']).mean()['rating'], 2)
print(f)
f1 = reviews[reviews['review'].isna() == True]['recipe_id']
f1.index = [i for i in range(len(f1))]
f1.head()
# Out:
# recipe_id
# 48        1.00
# 55        4.75
# 66        4.94
# 91        4.75
# 94        5.00
#           ...
# 536547    5.00
# 536610    0.00
# 536728    4.00
# 536729    4.75
# 536747    0.00
# Name: rating, Length: 28100, dtype: float64
# 0      9054
# 1    167202
# 2      9054
# 3    335709
# 4     15553
# Name: recipe_id, dtype: int64
